# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
# Out:
# 2024-04-14 18:47:11.710535: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-14 18:47:11.788309: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-14 18:47:11.788387: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-14 18:47:11.790634: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-14 18:47:11.802543: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
import os

# Load the model
model = tf.keras.models.load_model('model_best.hdf5')
print(model)

# Define the test image path
#test_image_path = 'test/Bacterial spot/BacterialSpot (13).JPG'

test_image_path = os.path.join('bell_pepper_dataset', 'Bell pepper Healthy', 'BellPepperHealthy_1043.jpg')


# Load and preprocess the test image
img = image.load_img(test_image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

# Make predictions
predictions = model.predict(img_array)

# Get the class with the highest probability
classified_labels = np.argmax(predictions, axis=1)
class_names = ['bell-pepper-bacterial-spot', 'bell-pepper-healthy','curling-leaves', 'Mosaic-virus', 'yellowing-leaves']
label = class_names[classified_labels[0]]

# Print the predicted label and confidence score
print(f'This image most likely belongs to {label} with a {np.max(predictions[0])*100:.2f} percent confidence.')
# Out:
# ...
# 1/1 [==============================] - 0s 104ms/step
# This image most likely belongs to bell-pepper-healthy with a 100.00 percent confidence.

# %%
import os

# Load the model
model = tf.keras.models.load_model('model_best.hdf5')

# Define the test image path
#test_image_path = 'test/Bacterial spot/BacterialSpot (13).JPG'

test_image_path = os.path.join('bell_pepper_dataset', 'Bacterial spot', 'BacterialSpot_1042.jpg')


# Load and preprocess the test image
img = image.load_img(test_image_path, target_size=(224, 224))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0

# Make predictions
predictions = model.predict(img_array)

# Get the class with the highest probability
classified_labels = np.argmax(predictions, axis=1)
class_names = ['bell-pepper-bacterial-spot', 'bell-pepper-healthy','curling-leaves', 'Mosaic-virus', 'yellowing-leaves']
label = class_names[classified_labels[0]]

# Print the predicted label and confidence score
print(f'This image most likely belongs to {label} with a {np.max(predictions[0])*100:.2f} percent confidence.')
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7163a851c5e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 104ms/step
# This image most likely belongs to bell-pepper-bacterial-spot with a 99.42 percent confidence.

# %%
import os

# Define the test image directory
test_image_dir = 'bell_pepper_dataset/Mosaic virus/'

# Get a list of all test images in the directory
test_image_files = [f for f in os.listdir(test_image_dir) if f.endswith('.jpg')]

# Loop through the test images and make predictions
for test_image_file in test_image_files:
    img_path = os.path.join(test_image_dir, test_image_file)
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    predictions = model.predict(img_array)
    classified_labels = np.argmax(predictions, axis=1)
    class_names = ['Bell-pepper-bacterial-spot', 'Bell-pepper-healthy','Curling-leaves', 'Mosaic-virus', 'Yellowing-leaves']
    label = class_names[classified_labels[0]]
    print(f'{test_image_file} most likely belongs to {label} with a {np.max(predictions[0])*100:.2f} percent confidence.')
# Out:
# 1/1 [==============================] - 0s 57ms/step
# Mosaic virus_682.jpg most likely belongs to Mosaic-virus with a 100.00 percent confidence.
# 1/1 [==============================] - 0s 56ms/step
# Mosaic virus_456.jpg most likely belongs to Curling-leaves with a 93.36 percent confidence.
# 1/1 [==============================] - 0s 62ms/step
# Mosaic virus_903.jpg most likely belongs to Mosaic-virus with a 82.17 percent confidence.
# 1/1 [==============================] - 0s 51ms/step
# Mosaic virus_786.jpg most likely belongs to Mosaic-virus with a 53.68 percent confidence.
# 1/1 [==============================] - 0s 54ms/step
# Mosaic virus_1064.jpg most likely belongs to Mosaic-virus with a 85.19 percent confidence.
# 1/1 [==============================] - 0s 53ms/step
# Mosaic virus_714.jpg most likely belongs to Mosaic-virus with a 98.96 percent confidence.
# 1/1 [==============================] - 0s 56ms/step
# ...

# %%
import os

# Define the test image directory
test_image_dir = 'bell_pepper_dataset/Curling leaves/'

# Get a list of all test images in the directory
test_image_files = [f for f in os.listdir(test_image_dir) if f.endswith('.jpg')]

# Loop through the test images and make predictions
for test_image_file in test_image_files:
    img_path = os.path.join(test_image_dir, test_image_file)
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    predictions = model.predict(img_array)
    classified_labels = np.argmax(predictions, axis=1)
    class_names = ['Bell-pepper-bacterial-spot', 'Bell-pepper-healthy','Curling-leaves', 'Mosaic-virus', 'Yellowing-leaves']
    label = class_names[classified_labels[0]]
    print(f'{test_image_file} most likely belongs to {label} with a {np.max(predictions[0])*100:.2f} percent confidence.')
# Out:
# 1/1 [==============================] - 0s 54ms/step
# curling leaf_1165.jpg most likely belongs to Curling-leaves with a 96.42 percent confidence.
# 1/1 [==============================] - 0s 52ms/step
# curling leaf_871.jpg most likely belongs to Curling-leaves with a 99.58 percent confidence.
# 1/1 [==============================] - 0s 55ms/step
# curling leaf_644.jpg most likely belongs to Curling-leaves with a 99.52 percent confidence.
# 1/1 [==============================] - 0s 53ms/step
# curling leaf_675.jpg most likely belongs to Curling-leaves with a 99.98 percent confidence.
# 1/1 [==============================] - 0s 53ms/step
# curling leaf_976.jpg most likely belongs to Curling-leaves with a 99.89 percent confidence.
# 1/1 [==============================] - 0s 56ms/step
# curling leaf_787.jpg most likely belongs to Curling-leaves with a 99.76 percent confidence.
# 1/1 [==============================] - 0s 51ms/step
# ...

# %%
import os

# Define the test image directory
test_image_dir = 'bell_pepper_dataset/Bacterial spot/'

# Get a list of all test images in the directory
test_image_files = [f for f in os.listdir(test_image_dir) if f.endswith('.jpg')]

# Loop through the test images and make predictions
for test_image_file in test_image_files:
    img_path = os.path.join(test_image_dir, test_image_file)
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    predictions = model.predict(img_array)
    classified_labels = np.argmax(predictions, axis=1)
    class_names = ['Bell-pepper-bacterial-spot', 'Bell-pepper-healthy','Curling-leaves', 'Mosaic-virus', 'Yellowing-leaves']
    label = class_names[classified_labels[0]]
    print(f'{test_image_file} most likely belongs to {label} with a {np.max(predictions[0])*100:.2f} percent confidence.')
# Out:
# 1/1 [==============================] - 0s 52ms/step
# BacterialSpot_160.jpg most likely belongs to Bell-pepper-bacterial-spot with a 98.48 percent confidence.
# 1/1 [==============================] - 0s 55ms/step
# BacterialSpot_753.jpg most likely belongs to Bell-pepper-bacterial-spot with a 97.21 percent confidence.
# 1/1 [==============================] - 0s 57ms/step
# BacterialSpot_660.jpg most likely belongs to Bell-pepper-bacterial-spot with a 53.02 percent confidence.
# 1/1 [==============================] - 0s 58ms/step
# BacterialSpot_1000.jpg most likely belongs to Bell-pepper-bacterial-spot with a 99.98 percent confidence.
# 1/1 [==============================] - 0s 50ms/step
# BacterialSpot_407.jpg most likely belongs to Bell-pepper-bacterial-spot with a 99.31 percent confidence.
# 1/1 [==============================] - 0s 54ms/step
# BacterialSpot_618.jpg most likely belongs to Bell-pepper-bacterial-spot with a 92.79 percent confidence.
# ...

# %%
import os

# Define the test image directory
test_image_dir = 'bell_pepper_dataset/Bell pepper Healthy/'

# Get a list of all test images in the directory
test_image_files = [f for f in os.listdir(test_image_dir) if f.endswith('.jpg')]

# Loop through the test images and make predictions
for test_image_file in test_image_files:
    img_path = os.path.join(test_image_dir, test_image_file)
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    predictions = model.predict(img_array)
    classified_labels = np.argmax(predictions, axis=1)
    class_names = ['Bell-pepper-bacterial-spot', 'Bell-pepper-healthy','Curling-leaves', 'Mosaic-virus', 'Yellowing-leaves']
    label = class_names[classified_labels[0]]
    print(f'{test_image_file} most likely belongs to {label} with a {np.max(predictions[0])*100:.2f} percent confidence.')
# Out:
# 1/1 [==============================] - 0s 48ms/step
# BellPepperHealthy_918.jpg most likely belongs to Bell-pepper-healthy with a 100.00 percent confidence.
# 1/1 [==============================] - 0s 54ms/step
# BellPepperHealthy_259.jpg most likely belongs to Bell-pepper-healthy with a 100.00 percent confidence.
# 1/1 [==============================] - 0s 60ms/step
# BellPepperHealthy_1049.jpg most likely belongs to Bell-pepper-healthy with a 100.00 percent confidence.
# 1/1 [==============================] - 0s 59ms/step
# BellPepperHealthy_549.jpg most likely belongs to Bell-pepper-healthy with a 96.59 percent confidence.
# 1/1 [==============================] - 0s 50ms/step
# BellPepperHealthy_613.jpg most likely belongs to Bell-pepper-healthy with a 100.00 percent confidence.
# 1/1 [==============================] - 0s 53ms/step
# BellPepperHealthy_806.jpg most likely belongs to Bell-pepper-healthy with a 100.00 percent confidence.
# ...

# %%
import os

# Define the test image directory
test_image_dir = 'bell_pepper_dataset/Yellowing leaves/'

# Get a list of all test images in the directory
test_image_files = [f for f in os.listdir(test_image_dir) if f.endswith('.jpg')]

# Loop through the test images and make predictions
for test_image_file in test_image_files:
    img_path = os.path.join(test_image_dir, test_image_file)
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    predictions = model.predict(img_array)
    classified_labels = np.argmax(predictions, axis=1)
    class_names = ['Bell-pepper-bacterial-spot', 'Bell-pepper-healthy','Curling-leaves', 'Mosaic-virus', 'Yellowing-leaves']
    label = class_names[classified_labels[0]]
    print(f'{test_image_file} most likely belongs to {label} with a {np.max(predictions[0])*100:.2f} percent confidence.')
# Out:
# 1/1 [==============================] - 0s 59ms/step
# yellowing leaf_733.jpg most likely belongs to Yellowing-leaves with a 100.00 percent confidence.
# 1/1 [==============================] - 0s 61ms/step
# yellowing leaf_1099.jpg most likely belongs to Yellowing-leaves with a 99.42 percent confidence.
# 1/1 [==============================] - 0s 61ms/step
# yellowing leaf_963.jpg most likely belongs to Yellowing-leaves with a 100.00 percent confidence.
# 1/1 [==============================] - 0s 53ms/step
# yellowing leaf_20.jpg most likely belongs to Yellowing-leaves with a 100.00 percent confidence.
# 1/1 [==============================] - 0s 52ms/step
# yellowing leaf_788.jpg most likely belongs to Yellowing-leaves with a 78.39 percent confidence.
# 1/1 [==============================] - 0s 53ms/step
# yellowing leaf_1079.jpg most likely belongs to Yellowing-leaves with a 100.00 percent confidence.
# 1/1 [==============================] - 0s 53ms/step
# ...
